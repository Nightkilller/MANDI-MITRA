# %% [markdown]
# # 04. LSTM Model Training
# Train the PyTorch LSTM with Bahdanau Attention model on MP mandi data.

# %%
import torch
import sys
sys.path.append('..')

from ml.training.config import TrainingConfig
from ml.training.train import train

config = TrainingConfig(epochs=50)
print("Ready for training!")
