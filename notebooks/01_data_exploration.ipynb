# %% [markdown]
# # 01. Data Exploration and EDA
# Explore historical scraping data from Agmarknet.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('../data/samples/sample_prices.csv')
df['date'] = pd.to_datetime(df['date'])
df.head()
